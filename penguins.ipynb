# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/AJITHA REDDY/Downloads/penguins_size.csv")

# %%
df.head(5).transpose()
# Out:
#                            0          1          2          3          4
# species               Adelie     Adelie     Adelie     Adelie     Adelie
# island             Torgersen  Torgersen  Torgersen  Torgersen  Torgersen
# culmen_length_mm        39.1       39.5       40.3        NaN       36.7
# culmen_depth_mm         18.7       17.4       18.0        NaN       19.3
# flipper_length_mm      181.0      186.0      195.0        NaN      193.0
# body_mass_g           3750.0     3800.0     3250.0        NaN     3450.0
# sex                     MALE     FEMALE     FEMALE        NaN     FEMALE

# %%
#UNIQUE SPECIES#

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
#CHECK FOR NULL VALUES#

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df[df['sex'].isna()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 8    Adelie  Torgersen              34.1             18.1              193.0
# 9    Adelie  Torgersen              42.0             20.2              190.0
# 10   Adelie  Torgersen              37.8             17.1              186.0
# 11   Adelie  Torgersen              37.8             17.3              180.0
# 47   Adelie      Dream              37.5             18.9              179.0
# 246  Gentoo     Biscoe              44.5             14.3              216.0
# 286  Gentoo     Biscoe              46.2             14.4              214.0
# 324  Gentoo     Biscoe              47.3             13.8              216.0
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 47        2975.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN
# 339          NaN  NaN

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
#CHECK FOR UNIQUENESS AND CORRECTNESS#

# %%
df[df['sex'] == '.']
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
#TO FIND WHAT COULD BE GENDER OF 336 #

# %%
df[df['species']=='Gentoo'].groupby('sex').describe().transpose()
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0    58.000000    61.000000
#                   mean     44.5    45.563793    49.473770
#                   std       NaN     2.051247     2.720594
#                   min      44.5    40.900000    44.400000
#                   25%      44.5    43.850000    48.100000
#                   50%      44.5    45.500000    49.500000
#                   75%      44.5    46.875000    50.500000
#                   max      44.5    50.500000    59.600000
# culmen_depth_mm   count     1.0    58.000000    61.000000
#                   mean     15.7    14.237931    15.718033
#                   std       NaN     0.540249     0.741060
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    13.800000    15.200000
#                   50%      15.7    14.250000    15.700000
#                   75%      15.7    14.600000    16.100000
#                   max      15.7    15.500000    17.300000
# flipper_length_mm count     1.0    58.000000    61.000000
#                   mean    217.0   212.706897   221.540984
#                   std       NaN     3.897856     5.673252
#                   min     217.0   203.000000   208.000000
#                   25%     217.0   210.000000   218.000000
#                   50%     217.0   212.000000   221.000000
#                   75%     217.0   215.000000   225.000000
#                   max     217.0   222.000000   231.000000
# body_mass_g       count     1.0    58.000000    61.000000
#                   mean   4875.0  4679.741379  5484.836066
#                   std       NaN   281.578294   313.158596
#                   min    4875.0  3950.000000  4750.000000
#                   25%    4875.0  4462.500000  5300.000000
#                   50%    4875.0  4700.000000  5500.000000
#                   75%    4875.0  4875.000000  5700.000000
#                   max    4875.0  5200.000000  6300.000000

# %%
df.at[336,'sex'] = 'FEMALE'

# %%
df.loc[336]
# Out:
# species              Gentoo
# island               Biscoe
# culmen_length_mm       44.5
# culmen_depth_mm        15.7
# flipper_length_mm     217.0
# body_mass_g          4875.0
# sex                  FEMALE
# Name: 336, dtype: object

# %%
sns.pairplot(df, hue = 'species')

# %%
df['island'].value_counts()
# Out:
# island
# Biscoe       164
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
#CATEGORICAL PLOT#

# %%
sns.catplot(data = df, x = 'species', y = 'culmen_length_mm', kind = 'box', col = 'sex')

# %%
pd.get_dummies(df).transpose()
# Out:
#                       0       1       2       4       5       6       7    \
# culmen_length_mm     39.1    39.5    40.3    36.7    39.3    38.9    39.2
# culmen_depth_mm      18.7    17.4    18.0    19.3    20.6    17.8    19.6
# flipper_length_mm   181.0   186.0   195.0   193.0   190.0   181.0   195.0
# body_mass_g        3750.0  3800.0  3250.0  3450.0  3650.0  3625.0  4675.0
# species_Adelie       True    True    True    True    True    True    True
# species_Chinstrap   False   False   False   False   False   False   False
# species_Gentoo      False   False   False   False   False   False   False
# island_Biscoe       False   False   False   False   False   False   False
# island_Dream        False   False   False   False   False   False   False
# island_Torgersen     True    True    True    True    True    True    True
# sex_FEMALE          False    True    True    True   False    True   False
# sex_MALE             True   False   False   False    True   False    True
#
#                       12      13      14   ...     333     334     335  \
# culmen_length_mm     41.1    38.6    34.6  ...    51.5    46.2    55.1
# culmen_depth_mm      17.6    21.2    21.1  ...    16.3    14.1    16.0
# flipper_length_mm   182.0   191.0   198.0  ...   230.0   217.0   230.0
# body_mass_g        3200.0  3800.0  4400.0  ...  5500.0  4375.0  5850.0
# species_Adelie       True    True    True  ...   False   False   False
# species_Chinstrap   False   False   False  ...   False   False   False
# species_Gentoo      False   False   False  ...    True    True    True
# island_Biscoe       False   False   False  ...    True    True    True
# island_Dream        False   False   False  ...   False   False   False
# island_Torgersen     True    True    True  ...   False   False   False
# sex_FEMALE           True   False   False  ...   False    True   False
# sex_MALE            False    True    True  ...    True   False    True
#
#                       336     337     338     340     341     342     343
# culmen_length_mm     44.5    48.8    47.2    46.8    50.4    45.2    49.9
# culmen_depth_mm      15.7    16.2    13.7    14.3    15.7    14.8    16.1
# flipper_length_mm   217.0   222.0   214.0   215.0   222.0   212.0   213.0
# body_mass_g        4875.0  6000.0  4925.0  4850.0  5750.0  5200.0  5400.0
# species_Adelie      False   False   False   False   False   False   False
# species_Chinstrap   False   False   False   False   False   False   False
# species_Gentoo       True    True    True    True    True    True    True
# island_Biscoe        True    True    True    True    True    True    True
# island_Dream        False   False   False   False   False   False   False
# island_Torgersen    False   False   False   False   False   False   False
# sex_FEMALE           True   False    True    True   False    True   False
# sex_MALE            False    True   False   False    True   False    True
#
# [12 rows x 334 columns]

# %%
X = pd.get_dummies(df.drop('species', axis=1),drop_first=True)

# %%
X.head()
# Out:
#    culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0              39.1             18.7              181.0       3750.0
# 1              39.5             17.4              186.0       3800.0
# 2              40.3             18.0              195.0       3250.0
# 4              36.7             19.3              193.0       3450.0
# 5              39.3             20.6              190.0       3650.0
#
#    island_Dream  island_Torgersen  sex_MALE
# 0         False              True      True
# 1         False              True     False
# 2         False              True     False
# 4         False              True     False
# 5         False              True      True

# %%
(X['island_Torgersen'] == False).sum()
# Out:
# 287

# %%
(X['island_Torgersen'] == True).sum()
# Out:
# 47

# %%
y = df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_preds = model.predict(X_test)

# %%
base_preds
# Out:
# array(['Adelie', 'Gentoo', 'Adelie', 'Chinstrap', 'Adelie', 'Gentoo',
#        'Gentoo', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Adelie', 'Gentoo', 'Adelie', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Gentoo',
#        'Chinstrap', 'Adelie', 'Adelie', 'Gentoo', 'Gentoo', 'Chinstrap',
#        'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie', 'Gentoo',
#        'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Chinstrap', 'Chinstrap', 'Adelie', 'Adelie', 'Gentoo',
#        'Adelie', 'Adelie', 'Gentoo', 'Adelie', 'Gentoo', 'Gentoo',
#        'Adelie', 'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap',
#        'Chinstrap', 'Gentoo', 'Gentoo', 'Gentoo', 'Adelie', 'Adelie',
#        'Gentoo', 'Adelie', 'Gentoo', 'Adelie', 'Gentoo', 'Adelie',
#        'Adelie', 'Gentoo', 'Gentoo', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Adelie', 'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo', 'Chinstrap',
#        'Chinstrap', 'Gentoo', 'Gentoo', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Chinstrap', 'Adelie', 'Adelie', 'Adelie'],
#       dtype=object)

# %%
y_test
# Out:
# 30        Adelie
# 317       Gentoo
# 79        Adelie
# 201    Chinstrap
# 63        Adelie
#          ...
# 7         Adelie
# 215    Chinstrap
# 99        Adelie
# 35        Adelie
# 27        Adelie
# Name: species, Length: 101, dtype: object

# %%
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay

# %%
print(classification_report(y_test, base_preds))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      0.98      0.98        49
#    Chinstrap       0.94      0.94      0.94        18
#       Gentoo       1.00      1.00      1.00        34
#
#     accuracy                           0.98       101
#    macro avg       0.97      0.97      0.97       101
# weighted avg       0.98      0.98      0.98       101

# %%
cm = confusion_matrix(y_test, base_preds, labels = model.classes_)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = model.classes_)
disp.plot()

# %%
model.feature_importances_
# Out:
# array([0.34590473, 0.0986586 , 0.50768009, 0.        , 0.03776629,
#        0.        , 0.00999028])

# %%
sum(model.feature_importances_)
# Out:
# 1.0

# %%
X.columns
# Out:
# Index(['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_g', 'island_Dream', 'island_Torgersen', 'sex_MALE'],
#       dtype='object')

# %%
pd.DataFrame(index=X.columns, data=model.feature_importances_, columns=['Feature Importance']).sort_values('Feature Importance')
# Out:
#                    Feature Importance
# body_mass_g                  0.000000
# island_Torgersen             0.000000
# sex_MALE                     0.009990
# island_Dream                 0.037766
# culmen_depth_mm              0.098659
# culmen_length_mm             0.345905
# flipper_length_mm            0.507680

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize = (12, 8), dpi = 200)
plot_tree(model,feature_names = X.columns, filled = True);

# %%
X_train
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 292              48.2             15.6              221.0       5100.0
# 302              47.4             14.6              212.0       4725.0
# 62               37.6             17.0              185.0       3600.0
# 181              52.8             20.0              205.0       4550.0
# 15               36.6             17.8              185.0       3700.0
# ..                ...              ...                ...          ...
# 194              50.9             19.1              196.0       3550.0
# 77               37.2             19.4              184.0       3900.0
# 112              39.7             17.7              193.0       3200.0
# 277              45.5             15.0              220.0       5000.0
# 108              38.1             17.0              181.0       3175.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 292         False             False      True
# 302         False             False     False
# 62          False             False     False
# 181          True             False      True
# 15          False              True     False
# ..            ...               ...       ...
# 194          True             False      True
# 77          False              True      True
# 112         False             False     False
# 277         False             False      True
# 108         False             False     False
#
# [233 rows x 7 columns]

# %%
def ReportModel(model):
    model_preds = model.predict(X_test)
    print(classification_report(y_test, model_preds))
    print('\n')
    plt.figure(figsize = (12, 8), dpi = 200)
    plot_tree(model,feature_names = X.columns, filled = True);

# %%
ReportModel(model)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      0.98      0.98        49
#    Chinstrap       0.94      0.94      0.94        18
#       Gentoo       1.00      1.00      1.00        34
#
#     accuracy                           0.98       101
#    macro avg       0.97      0.97      0.97       101
# weighted avg       0.98      0.98      0.98       101

# %%
pruned_tree = DecisionTreeClassifier(max_depth = 2)

# %%
pruned_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
ReportModel(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      1.00      0.98        49
#    Chinstrap       1.00      0.89      0.94        18
#       Gentoo       1.00      1.00      1.00        34
#
#     accuracy                           0.98       101
#    macro avg       0.99      0.96      0.97       101
# weighted avg       0.98      0.98      0.98       101

# %%
max_leaf_tree = DecisionTreeClassifier(max_leaf_nodes = 3)

# %%
max_leaf_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=3)

# %%
ReportModel(max_leaf_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      1.00      0.98        49
#    Chinstrap       1.00      0.83      0.91        18
#       Gentoo       0.97      1.00      0.99        34
#
#     accuracy                           0.97       101
#    macro avg       0.98      0.94      0.96       101
# weighted avg       0.97      0.97      0.97       101

# %%
entropy_tree = DecisionTreeClassifier(criterion = 'entropy')

# %%
entropy_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
ReportModel(entropy_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.98      0.98      0.98        49
#    Chinstrap       0.94      0.94      0.94        18
#       Gentoo       1.00      1.00      1.00        34
#
#     accuracy                           0.98       101
#    macro avg       0.97      0.97      0.97       101
# weighted avg       0.98      0.98      0.98       101
